# %%
import requests
import pandas as pd

# URL of the API
url = "https://opengis.detroitmi.gov/opengis/rest/services/PublicSafety/RMS_Crime_Incidents/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json"

# Make a GET request to the API
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Convert the JSON response to a DataFrame
    data = response.json()
    features = data.get("features", [])
    records = [feature["attributes"] for feature in features]
    df = pd.DataFrame.from_records(records)
    print(df.head())  # Display the first few rows of the DataFrame
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
#   crime_id report_number                                address  \
# 0  3009876    1701040208  W Outer Dr & Southfield Service Drive
# 1  3019688    1701310002                 Forrer St & Tireman St
# 2  3046707    1704050185               Lauder St & Margareta St
# 3  3046854    1704050314           Saint Marys St & Majestic St
# 4  3049535    1704110463                Celestine St & Young St
#
#     offense_description offense_category state_offense_code arrest_charge  \
# 0               ROBBERY          ROBBERY               1201         12000
# 1                 ARSON            ARSON               2099         20000
# 2       LARCENY - OTHER          LARCENY               2307         23007
# 3  LARCENY FROM GROUNDS          LARCENY               2307         23009
# 4                 ARSON            ARSON               2099         20000
#
#      charge_description  incident_timestamp incident_time  ...  \
# 0               ROBBERY       1483569000000         17:30  ...
# 1                 ARSON       1485001200000         07:20  ...
# 2       LARCENY - OTHER       1491368400000         01:00  ...
# 3  LARCENY FROM GROUNDS       1491439980000         20:53  ...
# 4                 ARSON       1491979080000         02:38  ...
#
#    scout_car_area  precinct         block_id          neighborhood  \
# 0            0808        08  261635404004019          College Park
# 1            0611        06  261635455001003  Warren Ave Community
# 2            1206        12  261635396003010               Winship
# 3            0611        06  261635455002001  Warren Ave Community
# 4            0906        09  261635005004009            Mapleridge
#
#   council_district zip_code  longitude   latitude      ibr_date  oid
# 0                2    48235 -83.218658  42.419085  1.519923e+12    1
# 1                7    48228 -83.200281  42.350847  1.494852e+12    2
# 2                2    48235 -83.192437  42.427032  1.494855e+12    3
# 3                7    48228 -83.203755  42.345960  1.494855e+12    4
# 4                4    48205 -82.972517  42.423891  1.494855e+12    5
#
# [5 rows x 23 columns]

# %%
# Set the max_columns option to None to display all columns
pd.set_option('display.max_columns', None)

# %%
df.head(5)
# Out:
#   crime_id report_number                                address  \
# 0  3009876    1701040208  W Outer Dr & Southfield Service Drive
# 1  3019688    1701310002                 Forrer St & Tireman St
# 2  3046707    1704050185               Lauder St & Margareta St
# 3  3046854    1704050314           Saint Marys St & Majestic St
# 4  3049535    1704110463                Celestine St & Young St
#
#     offense_description offense_category state_offense_code arrest_charge  \
# 0               ROBBERY          ROBBERY               1201         12000
# 1                 ARSON            ARSON               2099         20000
# 2       LARCENY - OTHER          LARCENY               2307         23007
# 3  LARCENY FROM GROUNDS          LARCENY               2307         23009
# 4                 ARSON            ARSON               2099         20000
#
#      charge_description  incident_timestamp incident_time  day_of_week  \
# 0               ROBBERY       1483569000000         17:30            3
# 1                 ARSON       1485001200000         07:20            6
# 2       LARCENY - OTHER       1491368400000         01:00            3
# 3  LARCENY FROM GROUNDS       1491439980000         20:53            3
# 4                 ARSON       1491979080000         02:38            3
#
#    hour_of_day  year scout_car_area precinct         block_id  \
# 0           17  2017           0808       08  261635404004019
# 1            7  2017           0611       06  261635455001003
# 2            1  2017           1206       12  261635396003010
# 3           20  2017           0611       06  261635455002001
# 4            2  2017           0906       09  261635005004009
#
#            neighborhood  council_district zip_code  longitude   latitude  \
# 0          College Park                 2    48235 -83.218658  42.419085
# 1  Warren Ave Community                 7    48228 -83.200281  42.350847
# 2               Winship                 2    48235 -83.192437  42.427032
# 3  Warren Ave Community                 7    48228 -83.203755  42.345960
# 4            Mapleridge                 4    48205 -82.972517  42.423891
#
#        ibr_date  oid
# 0  1.519923e+12    1
# 1  1.494852e+12    2
# 2  1.494855e+12    3
# 3  1.494855e+12    4
# 4  1.494855e+12    5

# %%
df.shape
# Out:
# (2000, 23)

# %%
df.address
# Out:
# 0       W Outer Dr & Southfield Service Drive
# 1                      Forrer St & Tireman St
# 2                    Lauder St & Margareta St
# 3                Saint Marys St & Majestic St
# 4                     Celestine St & Young St
#                         ...
# 1995               Pinehurst St & Tireman Ave
# 1996              Barlow St & E State Fair St
# 1997                    Cruse St & Keeler Ave
# 1998    Martin Luther King Jr Blvd & Cass Ave
# 1999                  E Hildale St & Mound Rd
# Name: address, Length: 2000, dtype: object

# %%
from homeharvest import scrape_property
from datetime import datetime

# Generate a filename based on the current timestamp
current_timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
filename = f"HomeHarvest_{current_timestamp}.csv"

# Scrape properties from Detroit, MI
properties = scrape_property(
    location="Los Angeles, CA",
    listing_type="sold",  # You can change this to 'for_sale', 'for_rent', or 'pending'
    past_days=600  # Modify this as needed
    # You can also use date_from and date_to instead of past_days
    # mls_only=True can be used to fetch only MLS listings
    # proxy="http://user:pass@host:port" to use a proxy
)

print(f"Number of properties: {len(properties)}")

# Export to CSV
#properties.to_csv(filename, index=False)
# Out:
# Number of properties: 10000

# %%
properties.head(5)
# Out:
#                                         property_url   mls       mls_id  \
# 0  https://www.realtor.com/realestateandhomes-det...  DEMI  20230086929
# 1  https://www.realtor.com/realestateandhomes-det...  DEMI  20230102573
# 2  https://www.realtor.com/realestateandhomes-det...  DEMI  20230026351
# 3  https://www.realtor.com/realestateandhomes-det...  DEMI  20230073000
# 4  https://www.realtor.com/realestateandhomes-det...  DEMI  20230073671
#
#   status          style                 street  unit     city state zip_code  \
# 0   SOLD  SINGLE_FAMILY       18285  Fenton St  None  Detroit    MI    48219
# 1   SOLD  SINGLE_FAMILY  3244 W Buena Vista St  None  Detroit    MI    48238
# 2   SOLD  SINGLE_FAMILY    15827  Faircrest St  None  Detroit    MI    48205
# 3   SOLD  SINGLE_FAMILY         8272  Freda St  None  Detroit    MI    48204
# 4   SOLD  SINGLE_FAMILY   6267  Grandville Ave  None  Detroit    MI    48228
#
#   beds full_baths half_baths  sqft year_built days_on_mls  list_price  \
# 0    3          1          1  1062       1966          85      119900
# 1    4          1          1  1482       1924          28       54900
# 2    4          1          1  1078       1940         189       65000
# 3    3          2       None  1680       1926         127      189000
# 4    3          1       None   868       1943         127       99900
#
#     list_date  sold_price last_sold_date lot_sqft price_per_sqft   latitude  \
# 0  2023-10-12      117000     2024-01-05     7405            110  42.422809
# 1  2023-12-08       45955     2024-01-05     3920             31  42.388846
# 2  2023-06-30       57000     2024-01-05     4792             53  42.432573
# 3  2023-08-31      172500     2024-01-05     4792            103  42.355176
# 4  2023-08-31       85000     2024-01-05     6098             98  42.335798
#
#    longitude stories hoa_fee parking_garage  \
# 0 -83.283036       1       0              2
# 1 -83.127056       2       0              2
# 2 -82.957487       2       0              2
# 3 -83.159627       2       0              2
# 4 -83.229379       2       0           None
#
#                                        primary_photo  \
# 0  http://ap.rdcpix.com/8c036dac2183996c598eecb08...
# 1  http://ap.rdcpix.com/70d36dc9448e47841bd88546a...
# 2  http://ap.rdcpix.com/7a1382de7150808377df892df...
# 3  http://ap.rdcpix.com/794a2012a90d3c6a7e442be00...
# 4  http://ap.rdcpix.com/a699fea729de953083ea50bcb...
#
#                                           alt_photos
# 0  http://ap.rdcpix.com/8c036dac2183996c598eecb08...
# 1  http://ap.rdcpix.com/70d36dc9448e47841bd88546a...
# 2  http://ap.rdcpix.com/7a1382de7150808377df892df...
# 3  http://ap.rdcpix.com/794a2012a90d3c6a7e442be00...
# 4  http://ap.rdcpix.com/a699fea729de953083ea50bcb...

# %%
from homeharvest import scrape_property
from datetime import datetime, timedelta

properties_list = []
start_date = datetime.now() - timedelta(days=400)  # Starting 600 days ago
end_date = datetime.now()
date_range = (end_date - start_date).days
days_per_request = date_range // 6  # Split into 6 requests

for i in range(6):
    date_from = start_date + timedelta(days=i*days_per_request)
    date_to = start_date + timedelta(days=(i+1)*days_per_request)

    partial_properties = scrape_property(
        location="Chicago, IL",
        listing_type="sold",
        date_from=date_from.strftime("%Y-%m-%d"),
        date_to=date_to.strftime("%Y-%m-%d")
    )

    print(f"Segment {i+1}, Number of properties: {len(partial_properties)}")
    properties_list.append(partial_properties)

# Combine all segments into one DataFrame
all_properties = pd.concat(properties_list, ignore_index=True)
print(f"Total Number of properties: {len(all_properties)}")

# Save to CSV
filename = "HomeHarvest_LosAngeles.csv"
all_properties.to_csv(filename, index=False)
# Out:
# Segment 1, Number of properties: 4590
# Segment 2, Number of properties: 5882
# Segment 3, Number of properties: 6687
# Segment 4, Number of properties: 5817
# Segment 5, Number of properties: 4807
# Segment 6, Number of properties: 3808
# Total Number of properties: 31591

# %%
from homeharvest import scrape_property
from datetime import datetime, timedelta

properties_list = []
start_date = datetime.now() - timedelta(days=500)
end_date = datetime.now()
date_range = (end_date - start_date).days
days_per_request = date_range // 12  # Now making 12 requests

for i in range(12):
    date_from = start_date + timedelta(days=i*days_per_request)
    date_to = start_date + timedelta(days=(i+1)*days_per_request)

    partial_properties = scrape_property(
        location="Chicago, IL",
        listing_type="sold",
        date_from=date_from.strftime("%Y-%m-%d"),
        date_to=date_to.strftime("%Y-%m-%d")
    )

    print(f"Segment {i+1}, Number of properties: {len(partial_properties)}")
    properties_list.append(partial_properties)

# Combine all segments into one DataFrame
all_properties = pd.concat(properties_list, ignore_index=True)
print(f"Total Number of properties: {len(all_properties)}")

# Save to CSV
filename = "HomeHarvest_Chicago.csv"
all_properties.to_csv(filename, index=False)
# Out:
# Segment 1, Number of properties: 4487
# Segment 2, Number of properties: 3784
# Segment 3, Number of properties: 3374
# Segment 4, Number of properties: 2676
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/dataclean.ipynb Cell 9 line 1
#      <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/dataclean.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a> date_from = start_date + timedelta(days=i*days_per_request)
#      <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/dataclean.ipynb#X11sZmlsZQ%3D%3D?line=11'>12</a> date_to = start_date + timedelta(days=(i+1)*days_per_request)
# ---> <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/dataclean.ipynb#X11sZmlsZQ%3D%3D?line=13'>14</a> partial_properties = scrape_property(
#      <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/dataclean.ipynb#X11sZmlsZQ%3D%3D?line=14'>15</a>     location="Chicago, IL",
#      <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/dataclean.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a>     listing_type="sold",
#      <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/dataclean.ipynb#X11sZmlsZQ%3D%3D?line=16'>17</a>     date_from=date_from.strftime("%Y-%m-%d"),
#      <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/dataclean.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a>     date_to=date_to.strftime("%Y-%m-%d")
#      <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/dataclean.ipynb#X11sZmlsZQ%3D%3D?line=18'>19</a> )
#      <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/dataclean.ipynb#X11sZmlsZQ%3D%3D?line=20'>21</a> print(f"Segment {i+1}, Number of properties: {len(partial_properties)}")
#      <a href='vscode-notebook-cell:/Users/rashidbaset/Documents/my-projects/crime-home-price-prediction-capstone/dataclean.ipynb#X11sZmlsZQ%3D%3D?line=21'>22</a> properties_list.append(partial_properties)
#
# File ~/anaconda3/lib/python3.11/site-packages/homeharvest/__init__.py:46, in scrape_property(location, listing_type, radius, mls_only, past_days, proxy, date_from, date_to)
#      43 site = RealtorScraper(scraper_input)
#      44 results = site.search()
# ---> 46 properties_dfs = [process_result(result) for result in results]
#      47 if not properties_dfs:
#      48     return pd.DataFrame()
#
# File ~/anaconda3/lib/python3.11/site-packages/homeharvest/__init__.py:46, in <listcomp>(.0)
#      43 site = RealtorScraper(scraper_input)
#      44 results = site.search()
# ---> 46 properties_dfs = [process_result(result) for result in results]
#      47 if not properties_dfs:
#      48     return pd.DataFrame()
#
# File ~/anaconda3/lib/python3.11/site-packages/homeharvest/utils.py:70, in process_result(result)
#      67 properties_df = pd.DataFrame([prop_data])
#      68 properties_df = properties_df.reindex(columns=ordered_properties)
# ---> 70 return properties_df[ordered_properties]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3767, in __getitem__(self, key)
#    3744 @property
#    3745 def T(self) -> DataFrame:
#    3746     """
#    3747     The transpose of the DataFrame.
#    3748
#    3749     Returns
#    3750     -------
#    3751     DataFrame
#    3752         The transposed DataFrame.
#    3753
#    3754     See Also
#    3755     --------
#    3756     DataFrame.transpose : Transpose index and columns.
#    3757
#    3758     Examples
#    3759     --------
#    3760     >>> df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
#    3761     >>> df
#    3762        col1  col2
#    3763     0     1     3
#    3764     1     2     4
#    3765
#    3766     >>> df.T
# -> 3767           0  1
#    3768     col1  1  2
#    3769     col2  3  4
#    3770     """
#    3771     return self.transpose()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:5869, in _get_indexer_strict(self, key, axis_name)
#    5864 @final
#    5865 def sort(self, *args, **kwargs):
#    5866     """
#    5867     Use sort_values instead.
#    5868     """
# -> 5869     raise TypeError("cannot sort an Index object in-place, use sort_values instead")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/common.py:242, in asarray_tuplesafe(values, dtype)
#     240         if not np_version_gte1p24:
#     241             warnings.simplefilter("ignore", np.VisibleDeprecationWarning)
# --> 242         result = np.asarray(values, dtype=dtype)
#     243 except ValueError:
#     244     # Using try/except since it's more performant than checking is_list_like
#     245     # over each element
#     246     # error: Argument 1 to "construct_1d_object_array_from_listlike"
#     247     # has incompatible type "Iterable[Any]"; expected "Sized"
#     248     return construct_1d_object_array_from_listlike(values)  # type: ignore[arg-type]
#
# KeyboardInterrupt:

# %%
from homeharvest import scrape_property
from datetime import datetime, timedelta

properties_list = []
start_date = datetime.now() - timedelta(days=500)
end_date = datetime.now()
date_range = (end_date - start_date).days
segments = 73  # Adjust the number of segments as necessary
days_per_request = date_range // segments

for i in range(segments):
    date_from = start_date + timedelta(days=i * days_per_request)
    date_to = date_from + timedelta(days=days_per_request)

    partial_properties = scrape_property(
        location="Chicago, IL",
        listing_type="sold",
        date_from=date_from.strftime("%Y-%m-%d"),
        date_to=date_to.strftime("%Y-%m-%d")
    )

    print(f"Segment {i+1}, Number of properties: {len(partial_properties)}")
    properties_list.append(partial_properties)

# Combine all segments into one DataFrame
all_properties = pd.concat(properties_list, ignore_index=True)
print(f"Total Number of properties: {len(all_properties)}")

# Save to CSV
filename = "HomeHarvest_Chicago.csv"
all_properties.to_csv(filename, index=False)
# Out:
# Segment 1, Number of properties: 863
# Segment 2, Number of properties: 995
# Segment 3, Number of properties: 676
# Segment 4, Number of properties: 813
# Segment 5, Number of properties: 555
# Segment 6, Number of properties: 488
# Segment 7, Number of properties: 772
# Segment 8, Number of properties: 533
# Segment 9, Number of properties: 625
# Segment 10, Number of properties: 668
# Segment 11, Number of properties: 637
# Segment 12, Number of properties: 801
# Segment 13, Number of properties: 542
# Segment 14, Number of properties: 549
# Segment 15, Number of properties: 670
# Segment 16, Number of properties: 366
# Segment 17, Number of properties: 687
# Segment 18, Number of properties: 473
# Segment 19, Number of properties: 564
# Segment 20, Number of properties: 631
# Segment 21, Number of properties: 495
# Segment 22, Number of properties: 451
# Segment 23, Number of properties: 433
# Segment 24, Number of properties: 472
# Segment 25, Number of properties: 414
# Segment 26, Number of properties: 444
# Segment 27, Number of properties: 492
# Segment 28, Number of properties: 378
# Segment 29, Number of properties: 421
# Segment 30, Number of properties: 436
# Segment 31, Number of properties: 426
# Segment 32, Number of properties: 670
# Segment 33, Number of properties: 584
# Segment 34, Number of properties: 745
# Segment 35, Number of properties: 775
# Segment 36, Number of properties: 626
# Segment 37, Number of properties: 833
# Segment 38, Number of properties: 736
# Segment 39, Number of properties: 711
# Segment 40, Number of properties: 759
# Segment 41, Number of properties: 702
# Segment 42, Number of properties: 1052
# Segment 43, Number of properties: 830
# Segment 44, Number of properties: 592
# Segment 45, Number of properties: 586
# Segment 46, Number of properties: 607
# Segment 47, Number of properties: 738
# Segment 48, Number of properties: 674
# Segment 49, Number of properties: 521
# Segment 50, Number of properties: 548
# Segment 51, Number of properties: 505
# Segment 52, Number of properties: 832
# Segment 53, Number of properties: 485
# Segment 54, Number of properties: 803
# Segment 55, Number of properties: 819
# Segment 56, Number of properties: 592
# Segment 57, Number of properties: 717
# Segment 58, Number of properties: 697
# Segment 59, Number of properties: 419
# Segment 60, Number of properties: 547
# Segment 61, Number of properties: 519
# Segment 62, Number of properties: 589
# Segment 63, Number of properties: 611
# Segment 64, Number of properties: 518
# Segment 65, Number of properties: 501
# Segment 66, Number of properties: 428
# Segment 67, Number of properties: 602
# Segment 68, Number of properties: 544
# Segment 69, Number of properties: 398
# Segment 70, Number of properties: 426
# Segment 71, Number of properties: 438
# Segment 72, Number of properties: 454
# Segment 73, Number of properties: 479
# Total Number of properties: 43982
