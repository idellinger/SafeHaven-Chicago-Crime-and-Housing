# %%
import requests
import pandas as pd

url = "https://data.cityofchicago.org/resource/9hwr-2zxp.json"
total_rows = 60000
chunk_size = 1000
offset = 0
dataframes = []

while offset < total_rows:
    params = {'$limit': chunk_size, '$offset': offset}
    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        if len(data) == 0:  
            break
        df = pd.DataFrame(data)
        dataframes.append(df)
        offset += chunk_size
    else:
        print("Failed to retrieve data. Status code:", response.status_code)
        break

final_df = pd.concat(dataframes, ignore_index=True)

print("Total rows retrieved:", len(final_df))
# Out:
# Total rows retrieved: 60000

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  60000 non-null  object
#  1   location              59205 non-null  object
#  2   district              60000 non-null  object
#  3   block                 60000 non-null  object
#  4   y_coordinate          59205 non-null  object
#  5   latitude              59205 non-null  object
#  6   description           60000 non-null  object
#  7   location_description  59758 non-null  object
#  8   updated_on            60000 non-null  object
#  9   community_area        60000 non-null  object
#  10  iucr                  60000 non-null  object
#  11  x_coordinate          59205 non-null  object
#  12  ward                  60000 non-null  object
#  13  case_number           60000 non-null  object
#  14  year                  60000 non-null  object
#  15  domestic              60000 non-null  bool
#  16  fbi_code              60000 non-null  object
#  17  longitude             59205 non-null  object
#  18  beat                  60000 non-null  object
#  19  primary_type          60000 non-null  object
#  20  arrest                60000 non-null  bool
#  21  id                    60000 non-null  object
# dtypes: bool(2), object(20)
# memory usage: 9.3+ MB
