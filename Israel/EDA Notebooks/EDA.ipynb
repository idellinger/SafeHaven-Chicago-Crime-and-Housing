# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np

# %%
database_file = 'C:\Data Science\chicago-crime-property-analysis\Israel\data\chicago-crime-property.db'
connection = sqlite3.connect(database_file)
cursor = connection.cursor()

table_1_query = "SELECT * FROM Crime"
table_2_query = "SELECT * FROM Property"

# %%
crime_df = pd.read_sql_query(table_1_query, connection)
house_df = pd.read_sql_query(table_2_query, connection)

connection.close()

# %%
crime_df.head()
# Out:
#                   date                                           location  \
# 0  2023-12-31 23:59:00  {'latitude': '41.900698378', 'human_address': ...
# 1  2023-12-31 23:51:00  {'latitude': '41.754966726', 'human_address': ...
# 2  2023-12-31 23:51:00  {'latitude': '41.801583507', 'human_address': ...
# 3  2023-12-31 23:50:00  {'latitude': '41.906519104', 'human_address': ...
# 4  2023-12-31 23:50:00  {'latitude': '41.800200965', 'human_address': ...
#
#    district                  block  y_coordinate   latitude  \
# 0        18     010XX N ORLEANS ST     1907173.0  41.900698
# 1         6        009XX E 77TH ST     1854148.0  41.754967
# 2         9  051XX S PRINCETON AVE     1871065.0  41.801584
# 3        25   014XX N LOCKWOOD AVE     1909050.0  41.906519
# 4         9  051XX S WASHTENAW AVE     1870437.0  41.800201
#
#                                          description location_description  \
# 0                                         TO VEHICLE               STREET
# 1                AGGRAVATED - OTHER DANGEROUS WEAPON            APARTMENT
# 2                AGGRAVATED POLICE OFFICER - HANDGUN               STREET
# 3  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...               STREET
# 4                            DOMESTIC BATTERY SIMPLE            RESIDENCE
#
#                 updated_on  community_area  ... ward  case_number  year  \
# 0  2024-01-08T15:59:56.000             8.0  ...   27     JH103488  2023
# 1  2024-01-08T15:59:56.000            69.0  ...    8     JH100010  2023
# 2  2024-01-08T15:59:56.000            37.0  ...   20     JH100002  2023
# 3  2024-01-08T15:59:56.000            25.0  ...   37     JG561343  2023
# 4  2024-01-08T15:59:56.000            63.0  ...   14     JH100006  2023
#
#   domestic  fbi_code  longitude  beat     primary_type  arrest        id
# 0        0        14 -87.637330  1823  CRIMINAL DAMAGE       0  13327763
# 1        1       04A -87.602411   624          ASSAULT       0  13324997
# 2        0       04A -87.633177   935          ASSAULT       0  13325009
# 3        0       08B -87.758360  2532          BATTERY       0  13324829
# 4        1       08B -87.691535   923          BATTERY       0  13324881
#
# [5 rows x 22 columns]

# %%
crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2530216 entries, 0 to 2530215
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   date                  object
#  1   location              object
#  2   district              int64
#  3   block                 object
#  4   y_coordinate          float64
#  5   latitude              float64
#  6   description           object
#  7   location_description  object
#  8   updated_on            object
#  9   community_area        float64
#  10  iucr                  object
#  11  x_coordinate          float64
#  12  ward                  int64
#  13  case_number           object
#  14  year                  int64
#  15  domestic              int64
#  16  fbi_code              object
#  17  longitude             float64
#  18  beat                  int64
#  19  primary_type          object
#  20  arrest                int64
#  21  id                    int64
# dtypes: float64(5), int64(7), object(10)
# memory usage: 424.7+ MB

# %%
house_df.head()
# Out:
#                                         property_url    mls_id          style  \
# 0  https://www.realtor.com/realestateandhomes-det...  08326275  SINGLE_FAMILY
# 1  https://www.realtor.com/realestateandhomes-det...      None  SINGLE_FAMILY
# 2  https://www.realtor.com/realestateandhomes-det...  08401495  SINGLE_FAMILY
# 3  https://www.realtor.com/realestateandhomes-det...  08530200   MULTI_FAMILY
# 4  https://www.realtor.com/realestateandhomes-det...  08461738  SINGLE_FAMILY
#
#                street  zip_code  beds  full_baths  half_baths  sqft  \
# 0    8548 S Bishop St   60620.0     3           1          -1  1350
# 1  7716 S Aberdeen St   60620.0     3           1          -1  1300
# 2  7837 S Wolcott Ave   60620.0     3           1           1   692
# 3  7807 S Sangamon St   60620.0     7           2          -1    -1
# 4  7541 S Aberdeen St   60620.0     2           1           1  1437
#
#    year_built  ...       community  area     shape_area  perimeter area_num_1  \
# 0        1890  ...  AUBURN GRESHAM     0  105065353.602          0         71
# 1        1916  ...  AUBURN GRESHAM     0  105065353.602          0         71
# 2        1951  ...  AUBURN GRESHAM     0  105065353.602          0         71
# 3          -1  ...  AUBURN GRESHAM     0  105065353.602          0         71
# 4        1922  ...  AUBURN GRESHAM     0  105065353.602          0         71
#
#    area_numbe  comarea_id  comarea      shape_len    neighborhood
# 0          71           0        0  46757.7217161  AUBURN GRESHAM
# 1          71           0        0  46757.7217161  AUBURN GRESHAM
# 2          71           0        0  46757.7217161  AUBURN GRESHAM
# 3          71           0        0  46757.7217161  AUBURN GRESHAM
# 4          71           0        0  46757.7217161  AUBURN GRESHAM
#
# [5 rows x 33 columns]

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313419 entries, 0 to 313418
# Data columns (total 33 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   property_url    313419 non-null  object
#  1   mls_id          165697 non-null  object
#  2   style           312967 non-null  object
#  3   street          313381 non-null  object
#  4   zip_code        313418 non-null  float64
#  5   beds            313419 non-null  int64
#  6   full_baths      313419 non-null  int64
#  7   half_baths      313419 non-null  int64
#  8   sqft            313419 non-null  int64
#  9   year_built      313419 non-null  int64
#  10  days_on_mls     313419 non-null  int64
#  11  list_price      313419 non-null  int64
#  12  list_date       165697 non-null  object
#  13  sold_price      313419 non-null  float64
#  14  last_sold_date  313419 non-null  object
#  15  lot_sqft        145360 non-null  float64
#  16  price_per_sqft  313419 non-null  float64
#  17  latitude        313419 non-null  float64
#  18  longitude       313419 non-null  float64
#  19  stories         313419 non-null  int64
#  20  hoa_fee         313419 non-null  float64
#  21  parking_garage  171335 non-null  float64
#  22  index_right     313419 non-null  int64
#  23  community       313419 non-null  object
#  24  area            313419 non-null  object
#  25  shape_area      313419 non-null  object
#  26  perimeter       313419 non-null  object
#  27  area_num_1      313419 non-null  object
#  28  area_numbe      313419 non-null  object
#  29  comarea_id      313419 non-null  object
#  30  comarea         313419 non-null  object
#  31  shape_len       313419 non-null  object
#  32  neighborhood    313419 non-null  object
# dtypes: float64(8), int64(9), object(16)
# memory usage: 78.9+ MB

# %% [markdown]
# # Exploring Missing Values: Property

# %%
house_missing_percentage = (house_df.isnull().sum() / len(house_df)) * 100
print(house_missing_percentage)
# Out:
# property_url       0.000000
# mls_id            47.132433
# style              0.144216
# street             0.012124
# zip_code           0.000319
# beds               0.000000
# full_baths         0.000000
# half_baths         0.000000
# sqft               0.000000
# year_built         0.000000
# days_on_mls        0.000000
# list_price         0.000000
# list_date         47.132433
# sold_price         0.000000
# last_sold_date     0.000000
# lot_sqft          53.621191
# price_per_sqft     0.000000
# latitude           0.000000
# longitude          0.000000
# stories            0.000000
# hoa_fee            0.000000
# parking_garage    45.333563
# index_right        0.000000
# community          0.000000
# area               0.000000
# shape_area         0.000000
# perimeter          0.000000
# area_num_1         0.000000
# area_numbe         0.000000
# comarea_id         0.000000
# comarea            0.000000
# shape_len          0.000000
# neighborhood       0.000000
# dtype: float64

# %%
crime_missing_percentage = (crime_df.isnull().sum() / len(crime_df)) * 100
print(crime_missing_percentage)
# Out:
# date                    0.000000
# location                1.506077
# district                0.000000
# block                   0.000000
# y_coordinate            0.000000
# latitude                0.000000
# description             0.000000
# location_description    0.432611
# updated_on              0.000000
# community_area          0.000079
# iucr                    0.000000
# x_coordinate            0.000000
# ward                    0.000000
# case_number             0.000000
# year                    0.000000
# domestic                0.000000
# fbi_code                0.000000
# longitude               0.000000
# beat                    0.000000
# primary_type            0.000000
# arrest                  0.000000
# id                      0.000000
# dtype: float64

# %%
house_df['hoa_fee'].value_counts()
# Out:
# hoa_fee
# -1.0        213088
#  0.0         34161
#  200.0         978
#  250.0         898
#  150.0         735
#              ...
#  4772.0          1
#  3733.0          1
#  16635.0         1
#  2461.0          1
#  1924.0          1
# Name: count, Length: 2824, dtype: int64

# %%
bin_condition_1 = (house_df['hoa_fee'] == 0) | (house_df['hoa_fee'] == -1)
bin_condition_2 = house_df['hoa_fee'] > 0

# Plotting the bar plot with two bins
plt.bar(['0 or -1', 'Above 0'], [house_df[bin_condition_1].shape[0], house_df[bin_condition_2].shape[0]], color=['blue', 'green'])
plt.xlabel('HOA Fees Bins')
plt.ylabel('Count')
plt.title('Distribution of HOA Fees')
plt.show()

# %% [markdown]
# Missing HOA Values are closely related to price. Lower property value Real Estate is less likely to have HOAs in general so this data doesn't contribute meaningfuly and can be safely dropped.

# %% [markdown]
# We already have the feature 'style' which describes the property and includes classification for apartment. The specific apartment number isn't of great use to us at the moment and can be safely dropped.

# %% [markdown]
# Similar to missing values for 'hoa_fees', 'half_baths' likely doesn't impact crime rates except as a bad substitute for property value and can safely be dropped. Likewise: 'full_baths', and 'beds'

# %%
cleaned_house_df = house_df.drop(columns=['lot_sqft','mls_id','hoa_fee','half_baths','full_baths', 'beds','stories','parking_garage'])
cleaned_house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313419 entries, 0 to 313418
# Data columns (total 26 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   property_url     313419 non-null  object
#  1   style            312967 non-null  object
#  2   street           313381 non-null  object
#  3   zip_code         313418 non-null  float64
#  4   sqft             313419 non-null  int64
#  5   year_built       313419 non-null  int64
#  6   days_on_mls      313419 non-null  int64
#  7   list_price       313419 non-null  int64
#  8   list_date        165697 non-null  object
#  9   sold_price       313419 non-null  float64
#  10  last_sold_date   313419 non-null  object
#  11  price_per_sqft   313419 non-null  float64
#  12  latitude         313419 non-null  float64
#  13  longitude        313419 non-null  float64
#  14  index_right      313419 non-null  int64
#  15  community        313419 non-null  object
#  16  area             313419 non-null  object
#  17  shape_area       313419 non-null  object
#  18  perimeter        313419 non-null  object
#  19  area_num_1       313419 non-null  object
#  20  area_numbe       313419 non-null  object
#  21  comarea_id       313419 non-null  object
#  22  comarea          313419 non-null  object
#  23  shape_len        313419 non-null  object
#  24  neighborhood     313419 non-null  object
#  25  sold_price_bins  310129 non-null  category
# dtypes: category(1), float64(5), int64(5), object(15)
# memory usage: 60.1+ MB

# %%
missing_percentage = (cleaned_house_df.isnull().sum() / len(house_df)) * 100
print(missing_percentage)
# Out:
# property_url        0.000000
# style               0.144216
# street              0.012124
# zip_code            0.000319
# sqft                0.000000
# year_built          0.000000
# days_on_mls         0.000000
# list_price          0.000000
# list_date          47.132433
# sold_price          0.000000
# last_sold_date      0.000000
# price_per_sqft      0.000000
# latitude            0.000000
# longitude           0.000000
# index_right         0.000000
# community           0.000000
# area                0.000000
# shape_area          0.000000
# perimeter           0.000000
# area_num_1          0.000000
# area_numbe          0.000000
# comarea_id          0.000000
# comarea             0.000000
# shape_len           0.000000
# neighborhood        0.000000
# sold_price_bins     1.049713
# dtype: float64

# %% [markdown]
# # Exploring Crime Data
